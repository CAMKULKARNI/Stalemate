# %%
import pandas as pd
import numpy as np
file = "D:\codes_python\sds project\games_normalized.csv"

# %%
games = pd.read_csv(file)

# %%
games.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
games
# Out:
#             id  rated     turns victory_status winner increment_code  \
# 0     fyfWyjj2    1.0 -0.050939         resign  black           10+6
# 1     QmCyfnNZ    1.0 -0.084366         resign  white           10+0
# 2     X1hUH5gY    1.0 -1.855974         resign  white        180+180
# 3     xfD25ZBl    1.0  1.787522         resign  white            9+5
# 4     BFo44qd4    1.0 -1.087163           mate  white           10+0
# ...        ...    ...       ...            ...    ...            ...
# 8002  SVScVlox    1.0 -0.151219           mate  white           30+0
# 8003  eBZNlH7w    1.0 -0.084366         resign  black           20+0
# 8004  MtDU2OuN    1.0 -0.920030           mate  black           20+5
# 8005  wL5yxYVK    1.0  0.116194         resign  white          15+15
# 8006  W1fKatN0    0.0 -0.552338         resign  black           30+0
#
#            white_id  white_rating         black_id  black_rating  \
# 0          mindworm      2.173746          lolmens      2.015920
# ...

# %%
games.corr(method = "pearson")
# Out:
#                  rated     turns  white_rating  black_rating  opening_ply  \
# rated         1.000000  0.084181      0.040615      0.044667    -0.005659
# turns         0.084181  1.000000      0.125498      0.148462     0.027065
# white_rating  0.040615  0.125498      1.000000      0.627895     0.221808
# black_rating  0.044667  0.148462      0.627895      1.000000     0.188611
# opening_ply  -0.005659  0.027065      0.221808      0.188611     1.000000
# game_time     0.006190  0.607349      0.070377      0.101690     0.042812
#
#               game_time
# rated          0.006190
# turns          0.607349
# white_rating   0.070377
# black_rating   0.101690
# opening_ply    0.042812
# game_time      1.000000

# %%
games.corr(method = "kendall")
# Out:
#                  rated     turns  white_rating  black_rating  opening_ply  \
# rated         1.000000  0.075697      0.039230      0.042973    -0.001535
# turns         0.075697  1.000000      0.088472      0.104311     0.019009
# white_rating  0.039230  0.088472      1.000000      0.478815     0.152280
# black_rating  0.042973  0.104311      0.478815      1.000000     0.127226
# opening_ply  -0.001535  0.019009      0.152280      0.127226     1.000000
# game_time     0.014252  0.506609      0.050662      0.071966     0.030664
#
#               game_time
# rated          0.014252
# turns          0.506609
# white_rating   0.050662
# black_rating   0.071966
# opening_ply    0.030664
# game_time      1.000000

# %%
games.corr(method = "spearman")
# Out:
#                  rated     turns  white_rating  black_rating  opening_ply  \
# rated         1.000000  0.092248      0.047992      0.052559    -0.001772
# turns         0.092248  1.000000      0.131441      0.154575     0.026803
# white_rating  0.047992  0.131441      1.000000      0.645496     0.212633
# black_rating  0.052559  0.154575      0.645496      1.000000     0.177928
# opening_ply  -0.001772  0.026803      0.212633      0.177928     1.000000
# game_time     0.017454  0.684416      0.075928      0.107602     0.043466
#
#               game_time
# rated          0.017454
# turns          0.684416
# white_rating   0.075928
# black_rating   0.107602
# opening_ply    0.043466
# game_time      1.000000

# %%
from itertools import combinations
columns = ["rated", "turns", "white_rating","black_rating", "opening_ply", "game_time"]
columns_combinations = list(combinations(columns, 2))

# %%
columns_combinations
# Out:
# [('rated', 'turns'),
#  ('rated', 'white_rating'),
#  ('rated', 'black_rating'),
#  ('rated', 'opening_ply'),
#  ('rated', 'game_time'),
#  ('turns', 'white_rating'),
#  ('turns', 'black_rating'),
#  ('turns', 'opening_ply'),
#  ('turns', 'game_time'),
#  ('white_rating', 'black_rating'),
#  ('white_rating', 'opening_ply'),
#  ('white_rating', 'game_time'),
#  ('black_rating', 'opening_ply'),
#  ('black_rating', 'game_time'),
#  ('opening_ply', 'game_time')]

# %%
import matplotlib.pyplot as plt
for i in columns_combinations:
    plt.scatter(games[i[0]], games[i[1]])
    plt.xlabel(i[0]) 
    plt.ylabel(i[1]) 
    plt.show()

# %%
new_file = "D:\codes_python\sds project\games_cleaned_withoutOutliers.csv"

# %%
new_games = pd.read_csv(new_file)

# %%
new_games.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
new_games
# Out:
#             id  rated  turns victory_status winner increment_code  \
# 0     fyfWyjj2    1.0   56.0         resign  black           10+6
# 1     QmCyfnNZ    1.0   55.0         resign  white           10+0
# 2     X1hUH5gY    1.0    2.0         resign  white        180+180
# 3     xfD25ZBl    1.0  111.0         resign  white            9+5
# 4     BFo44qd4    1.0   25.0           mate  white           10+0
# ...        ...    ...    ...            ...    ...            ...
# 8002  SVScVlox    1.0   53.0           mate  white           30+0
# 8003  eBZNlH7w    1.0   55.0         resign  black           20+0
# 8004  MtDU2OuN    1.0   30.0           mate  black           20+5
# 8005  wL5yxYVK    1.0   61.0         resign  white          15+15
# 8006  W1fKatN0    0.0   41.0         resign  black           30+0
#
#            white_id  white_rating         black_id  black_rating  \
# 0          mindworm        2180.0          lolmens        2134.0
# ...

# %%
new_columns = ["rated", "turns", "white_rating","black_rating", "opening_ply", "game_time"]
new_columns_combinations = list(combinations(new_columns, 2))

# %%
for i in new_columns_combinations:
    plt.scatter(new_games[i[0]], new_games[i[1]])
    plt.xlabel(i[0]) 
    plt.ylabel(i[1]) 
    plt.show()

# %%
sample = games.sample(frac = 0.3)

# %%
sample
# Out:
#             id  rated     turns victory_status winner  \
# 6682  wNJGpLQ5    1.0 -1.488281           mate  white
# 6804  IxL5TBNF    1.0 -1.855974         resign  white
# 6551  4bLU1gPD    0.0 -0.485485         resign  white
# 4964  5LNM4UKG    0.0  0.450459           mate  white
# 6355  ILxgRGiu    0.0  0.350179         resign  black
# ...        ...    ...       ...            ...    ...
# 3317  Xg0pELgT    1.0  0.450459         resign  white
# 3876  DlEsO7TI    1.0 -0.351778         resign  white
# 4998  janUi9Nr    1.0 -0.017513         resign  white
# 1163  2YYslt7b    1.0  0.818151         resign  black
# 1283  aq5q3fp8    1.0 -0.886603         resign  white
#
#                   increment_code         white_id  white_rating  \
# 6682                        10+0  mikhail_riemann      0.607378
# 6804                        10+0       aaaaaaaddd      0.577754
# 6551                        10+0          zen3000     -0.344293
# ...

# %%
sample.describe()
# Out:
#              rated        turns  white_rating  black_rating  opening_ply  \
# count  2402.000000  2402.000000   2402.000000   2402.000000  2402.000000
# mean      0.819734     0.012059     -0.011579     -0.009940     4.448793
# std       0.384489     1.004994      0.988690      0.999778     2.259526
# min       0.000000    -1.855974     -2.721618     -2.698599     1.000000
# 25%       1.000000    -0.686044     -0.680340     -0.687562     3.000000
# 50%       1.000000    -0.151219     -0.088786     -0.083514     4.000000
# 75%       1.000000     0.651019      0.651814      0.633793     6.000000
# max       1.000000     2.857172      2.803256      2.859377    10.000000
#
#          game_time
# count  2402.000000
# mean      0.026450
# std       1.034518
# min      -1.611992
# 25%      -0.768044
# 50%      -0.129757
# 75%       0.650886
# max       3.160476

# %%
for i in new_columns_combinations:
    plt.scatter(sample[i[0]], sample[i[1]])
    plt.xlabel(i[0]) 
    plt.ylabel(i[1]) 
    plt.show()

# %%
new_sample = new_games.sample(frac = 0.3)

# %%
new_sample.describe()
# Out:
#              rated        turns  white_rating  black_rating  opening_ply  \
# count  2402.000000  2402.000000   2402.000000   2402.000000  2402.000000
# mean      0.818068    58.215237   1588.666606   1579.508876     4.514155
# std       0.385869    30.044987    270.041912    271.034419     2.223087
# min       0.000000     2.000000    858.000000    857.000000     1.000000
# 25%       1.000000    37.000000   1403.000000   1392.000000     3.000000
# 50%       1.000000    54.000000   1569.000000   1562.000000     4.000000
# 75%       1.000000    77.000000   1772.000000   1765.000000     6.000000
# max       1.000000   143.000000   2344.000000   2337.000000    10.000000
#
#          game_time
# count  2402.000000
# mean    110.669785
# std      67.488197
# min       0.571333
# 25%      58.357167
# 50%     101.360250
# 75%     152.364375
# max     327.176000

# %%
for i in new_columns_combinations:
    plt.scatter(new_sample[i[0]], new_sample[i[1]])
    plt.xlabel(i[0]) 
    plt.ylabel(i[1]) 
    plt.show()

# %% [markdown]
# From the above plots we can see that the plots black_rating vs white_rating and game_time vs turns are the only ones which have a correlation between them. They are positively correlated
